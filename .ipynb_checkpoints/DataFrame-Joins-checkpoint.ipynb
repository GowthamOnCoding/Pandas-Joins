# %% [markdown]
# # Innerjoin using merge method

# %%
import pandas as pd
week1=pd.read_csv("Restaurant - Week 1 Sales.csv")
week2=pd.read_csv("Restaurant - Week 2 Sales.csv")
week2.head(2)
# Out:
#    Customer ID  Food ID
# 0          688       10
# 1          813        7

# %%
week1.head(2)
# Out:
#    Customer ID  Food ID
# 0          537        9
# 1           97        4

# %%
#In our case both the dataframes have the common column names Customer Id and 
#We are going to perform inner join on that column
week1.merge(week2,how="inner",on="Customer ID")
# Out:
#     Customer ID  Food ID_x  Food ID_y
# 0           537          9          5
# 1           155          9          3
# 2           155          1          3
# 3           503          5          8
# 4           503          5          9
# 5           550          6          7
# 6           101          7          4
# 7            75          6          4
# 8            77          1          7
# 9            77          9          7
# 10           77          2          7
# 11           77          9          7
# 12          628          4          7
# 13          798          9          5
# 14          798          1          5
# 15          462          3          8
# 16          304          3          3
# 17          304          2          3
# 18          189          4          5
# 19          799          8          7
# 20           30          2          4
# 21          249          9          6
# 22          677         10          3
# 23          741          3          8
# 24          540          3          3
# 25          819          4          5
# 26          937         10         10
# 27          937         10          2
# 28          233          3          3
# 29           21          4          4
# ..          ...        ...        ...
# 32          816          7          2
# 33          761          9          2
# 34          761          9          3
# 35           80          2          4
# 36          479          6          3
# 37          922          1          1
# 38          922          1          2
# 39          909          1          6
# 40          909          4          6
# 41          919         10          8
# 42          574         10          9
# 43           45          7          8
# 44          529          7         10
# 45          673          7          4
# 46          310          2          5
# 47          310          1          5
# 48          867          9         10
# 49          968          1          4
# 50          482          3          1
# 51          163          1         10
# 52          321          1          3
# 53          783          6         10
# 54          578          5          5
# 55          578          5          5
# 56          520          8          7
# 57          945          5          4
# 58          343          3          5
# 59          343          3          2
# 60          343          3          7
# 61          621          9          6
#
# [62 rows x 3 columns]

# %% [markdown]
# Signature:
# week1.merge(
#     right,
#     how='inner',
#     on=None,
#     left_on=None,
#     right_on=None,
#     left_index=False,
#     right_index=False,
#     sort=False,
#     suffixes=('_x', '_y'),
#     copy=True,
#     indicator=False,
#     validate=None,
# )

# %%
#We can see that Pandas added suffixes to differentiate the dataframes
#To change the suffixes
week1.merge(week2,how="inner",suffixes=("_week1","_week2"),on="Customer ID")
# Out:
#     Customer ID  Food ID_week1  Food ID_week2
# 0           537              9              5
# 1           155              9              3
# 2           155              1              3
# 3           503              5              8
# 4           503              5              9
# 5           550              6              7
# 6           101              7              4
# 7            75              6              4
# 8            77              1              7
# 9            77              9              7
# 10           77              2              7
# 11           77              9              7
# 12          628              4              7
# 13          798              9              5
# 14          798              1              5
# 15          462              3              8
# 16          304              3              3
# 17          304              2              3
# 18          189              4              5
# 19          799              8              7
# 20           30              2              4
# 21          249              9              6
# 22          677             10              3
# 23          741              3              8
# 24          540              3              3
# 25          819              4              5
# 26          937             10             10
# 27          937             10              2
# 28          233              3              3
# 29           21              4              4
# ..          ...            ...            ...
# 32          816              7              2
# 33          761              9              2
# 34          761              9              3
# 35           80              2              4
# 36          479              6              3
# 37          922              1              1
# 38          922              1              2
# 39          909              1              6
# 40          909              4              6
# 41          919             10              8
# 42          574             10              9
# 43           45              7              8
# 44          529              7             10
# 45          673              7              4
# 46          310              2              5
# 47          310              1              5
# 48          867              9             10
# 49          968              1              4
# 50          482              3              1
# 51          163              1             10
# 52          321              1              3
# 53          783              6             10
# 54          578              5              5
# 55          578              5              5
# 56          520              8              7
# 57          945              5              4
# 58          343              3              5
# 59          343              3              2
# 60          343              3              7
# 61          621              9              6
#
# [62 rows x 3 columns]

# %%
#Joining on multiple columns
week1.merge(week2,how="inner",on=["Customer ID","Food ID"])
# Out:
#    Customer ID  Food ID
# 0          304        3
# 1          540        3
# 2          937       10
# 3          233        3
# 4           21        4
# 5           21        4
# 6          922        1
# 7          578        5
# 8          578        5

# %% [markdown]
# # Outer join

# %%
week1.merge(week2,how="outer",on="Customer ID",suffixes=["_Week1","_Week2"])
# Out:
#      Customer ID  Food ID_Week1  Food ID_Week2
# 0            537            9.0            5.0
# 1             97            4.0            NaN
# 2            658            1.0            NaN
# 3            202            2.0            NaN
# 4            155            9.0            3.0
# 5            155            1.0            3.0
# 6            213            8.0            NaN
# 7            600            1.0            NaN
# 8            503            5.0            8.0
# 9            503            5.0            9.0
# 10            71            3.0            NaN
# 11            71            8.0            NaN
# 12           174            3.0            NaN
# 13           961            9.0            NaN
# 14           966            5.0            NaN
# 15           641            4.0            NaN
# 16           288            2.0            NaN
# 17           149            4.0            NaN
# 18           954            2.0            NaN
# 19           147            9.0            NaN
# 20           147            8.0            NaN
# 21           550            6.0            7.0
# 22           101            7.0            4.0
# 23           549            6.0            NaN
# 24            75            6.0            4.0
# 25            78            7.0            NaN
# 26           514            5.0            NaN
# 27           833            7.0            NaN
# 28           833            3.0            NaN
# 29           329            8.0            NaN
# ..           ...            ...            ...
# 424          622            NaN            9.0
# 425          959            NaN            4.0
# 426          959            NaN            2.0
# 427          810            NaN            2.0
# 428          488            NaN            2.0
# 429          188            NaN            8.0
# 430          305            NaN            2.0
# 431          869            NaN            7.0
# 432          131            NaN            1.0
# 433          208            NaN            4.0
# 434          145            NaN            5.0
# 435          794            NaN            6.0
# 436          734            NaN           10.0
# 437          734            NaN            1.0
# 438          735            NaN            2.0
# 439          940            NaN            8.0
# 440          571            NaN            7.0
# 441          888            NaN            2.0
# 442          664            NaN            6.0
# 443          143            NaN            4.0
# 444          505            NaN            3.0
# 445           54            NaN            8.0
# 446          367            NaN            8.0
# 447          883            NaN            8.0
# 448          251            NaN            9.0
# 449          855            NaN            4.0
# 450          559            NaN           10.0
# 451          276            NaN            4.0
# 452          556            NaN           10.0
# 453          252            NaN            9.0
#
# [454 rows x 3 columns]

# %% [raw]
# Above result contains information about the customers who came in week1 or week2 or both

# %%
outer=week1.merge(week2,how="outer",on="Customer ID",indicator=True)
outer.head(25)
# Out:
#     Customer ID  Food ID_x  Food ID_y     _merge
# 0           537        9.0        5.0       both
# 1            97        4.0        NaN  left_only
# 2           658        1.0        NaN  left_only
# 3           202        2.0        NaN  left_only
# 4           155        9.0        3.0       both
# 5           155        1.0        3.0       both
# 6           213        8.0        NaN  left_only
# 7           600        1.0        NaN  left_only
# 8           503        5.0        8.0       both
# 9           503        5.0        9.0       both
# 10           71        3.0        NaN  left_only
# 11           71        8.0        NaN  left_only
# 12          174        3.0        NaN  left_only
# 13          961        9.0        NaN  left_only
# 14          966        5.0        NaN  left_only
# 15          641        4.0        NaN  left_only
# 16          288        2.0        NaN  left_only
# 17          149        4.0        NaN  left_only
# 18          954        2.0        NaN  left_only
# 19          147        9.0        NaN  left_only
# 20          147        8.0        NaN  left_only
# 21          550        6.0        7.0       both
# 22          101        7.0        4.0       both
# 23          549        6.0        NaN  left_only
# 24           75        6.0        4.0       both

# %% [markdown]
# Using the column _merge, we can know whether the data is present in both the dataframe or not
# Even we can use that column to perform operations like removing the common values and having the data either in week1 or week2

# %%
mask=outer["_merge"].isin(["left_only","right_only"])
outer[mask]
# Out:
#      Customer ID  Food ID_x  Food ID_y      _merge
# 1             97        4.0        NaN   left_only
# 2            658        1.0        NaN   left_only
# 3            202        2.0        NaN   left_only
# 6            213        8.0        NaN   left_only
# 7            600        1.0        NaN   left_only
# 10            71        3.0        NaN   left_only
# 11            71        8.0        NaN   left_only
# 12           174        3.0        NaN   left_only
# 13           961        9.0        NaN   left_only
# 14           966        5.0        NaN   left_only
# 15           641        4.0        NaN   left_only
# 16           288        2.0        NaN   left_only
# 17           149        4.0        NaN   left_only
# 18           954        2.0        NaN   left_only
# 19           147        9.0        NaN   left_only
# 20           147        8.0        NaN   left_only
# 23           549        6.0        NaN   left_only
# 25            78        7.0        NaN   left_only
# 26           514        5.0        NaN   left_only
# 27           833        7.0        NaN   left_only
# 28           833        3.0        NaN   left_only
# 29           329        8.0        NaN   left_only
# 30           586       10.0        NaN   left_only
# 31           341        1.0        NaN   left_only
# 32           519       10.0        NaN   left_only
# 33           680        9.0        NaN   left_only
# 34           419        7.0        NaN   left_only
# 35            20        1.0        NaN   left_only
# 36           822        6.0        NaN   left_only
# 37           226       10.0        NaN   left_only
# ..           ...        ...        ...         ...
# 424          622        NaN        9.0  right_only
# 425          959        NaN        4.0  right_only
# 426          959        NaN        2.0  right_only
# 427          810        NaN        2.0  right_only
# 428          488        NaN        2.0  right_only
# 429          188        NaN        8.0  right_only
# 430          305        NaN        2.0  right_only
# 431          869        NaN        7.0  right_only
# 432          131        NaN        1.0  right_only
# 433          208        NaN        4.0  right_only
# 434          145        NaN        5.0  right_only
# 435          794        NaN        6.0  right_only
# 436          734        NaN       10.0  right_only
# 437          734        NaN        1.0  right_only
# 438          735        NaN        2.0  right_only
# 439          940        NaN        8.0  right_only
# 440          571        NaN        7.0  right_only
# 441          888        NaN        2.0  right_only
# 442          664        NaN        6.0  right_only
# 443          143        NaN        4.0  right_only
# 444          505        NaN        3.0  right_only
# 445           54        NaN        8.0  right_only
# 446          367        NaN        8.0  right_only
# 447          883        NaN        8.0  right_only
# 448          251        NaN        9.0  right_only
# 449          855        NaN        4.0  right_only
# 450          559        NaN       10.0  right_only
# 451          276        NaN        4.0  right_only
# 452          556        NaN       10.0  right_only
# 453          252        NaN        9.0  right_only
#
# [392 rows x 4 columns]

# %% [markdown]
# # Left join

# %%
food=pd.read_csv("Restaurant - Foods.csv")
food.head(2)
# Out:
#    Food ID Food Item  Price
# 0        1     Sushi   3.99
# 1        2   Burrito   9.99

# %%
week1.head(2)
# Out:
#    Customer ID  Food ID
# 0          537        9
# 1           97        4

# %%
#Left join on food
week1.merge(food,how="left",on="Food ID")
# Out:
#      Customer ID  Food ID   Food Item  Price
# 0            537        9       Donut   0.99
# 1             97        4  Quesadilla   4.25
# 2            658        1       Sushi   3.99
# 3            202        2     Burrito   9.99
# 4            155        9       Donut   0.99
# 5            213        8       Salad  11.25
# 6            600        1       Sushi   3.99
# 7            503        5       Pizza   2.49
# 8             71        3        Taco   2.99
# 9            174        3        Taco   2.99
# 10           961        9       Donut   0.99
# 11           966        5       Pizza   2.49
# 12           641        4  Quesadilla   4.25
# 13           288        2     Burrito   9.99
# 14           149        4  Quesadilla   4.25
# 15           954        2     Burrito   9.99
# 16           147        9       Donut   0.99
# 17           155        1       Sushi   3.99
# 18           550        6       Pasta  13.99
# 19           101        7       Steak  24.99
# 20           549        6       Pasta  13.99
# 21            75        6       Pasta  13.99
# 22            78        7       Steak  24.99
# 23           514        5       Pizza   2.49
# 24           833        7       Steak  24.99
# 25           329        8       Salad  11.25
# 26           586       10       Drink   1.75
# 27           341        1       Sushi   3.99
# 28           519       10       Drink   1.75
# 29           680        9       Donut   0.99
# ..           ...      ...         ...    ...
# 220          147        8       Salad  11.25
# 221          745        4  Quesadilla   4.25
# 222          184        3        Taco   2.99
# 223          828        8       Salad  11.25
# 224          578        5       Pizza   2.49
# 225          491        4  Quesadilla   4.25
# 226           62        4  Quesadilla   4.25
# 227           77        9       Donut   0.99
# 228          506        9       Donut   0.99
# 229          271        9       Donut   0.99
# 230          584       10       Drink   1.75
# 231          148        5       Pizza   2.49
# 232          595        3        Taco   2.99
# 233          274       10       Drink   1.75
# 234          646        1       Sushi   3.99
# 235          520        8       Salad  11.25
# 236          644        8       Salad  11.25
# 237          725        8       Salad  11.25
# 238          934        4  Quesadilla   4.25
# 239          151       10       Drink   1.75
# 240          945        5       Pizza   2.49
# 241          343        3        Taco   2.99
# 242          380        9       Donut   0.99
# 243          911        4  Quesadilla   4.25
# 244          621        9       Donut   0.99
# 245          413        9       Donut   0.99
# 246          926        6       Pasta  13.99
# 247          134        3        Taco   2.99
# 248          396        6       Pasta  13.99
# 249          535       10       Drink   1.75
#
# [250 rows x 4 columns]

# %%
week1.merge(food,how="left",on="Food ID",sort=True)
#By using sort=True, we can sort the merged dataframe by the joining column provided, here Food ID
# Out:
#      Customer ID  Food ID Food Item  Price
# 0            658        1     Sushi   3.99
# 1            600        1     Sushi   3.99
# 2            155        1     Sushi   3.99
# 3            341        1     Sushi   3.99
# 4             20        1     Sushi   3.99
# 5             77        1     Sushi   3.99
# 6            100        1     Sushi   3.99
# 7            953        1     Sushi   3.99
# 8            504        1     Sushi   3.99
# 9            323        1     Sushi   3.99
# 10           922        1     Sushi   3.99
# 11           909        1     Sushi   3.99
# 12           602        1     Sushi   3.99
# 13            74        1     Sushi   3.99
# 14           703        1     Sushi   3.99
# 15           962        1     Sushi   3.99
# 16           968        1     Sushi   3.99
# 17           190        1     Sushi   3.99
# 18           163        1     Sushi   3.99
# 19           321        1     Sushi   3.99
# 20           310        1     Sushi   3.99
# 21           798        1     Sushi   3.99
# 22            92        1     Sushi   3.99
# 23           646        1     Sushi   3.99
# 24           202        2   Burrito   9.99
# 25           288        2   Burrito   9.99
# 26           954        2   Burrito   9.99
# 27           203        2   Burrito   9.99
# 28           876        2   Burrito   9.99
# 29            30        2   Burrito   9.99
# ..           ...      ...       ...    ...
# 220           77        9     Donut   0.99
# 221          506        9     Donut   0.99
# 222          271        9     Donut   0.99
# 223          380        9     Donut   0.99
# 224          621        9     Donut   0.99
# 225          413        9     Donut   0.99
# 226          586       10     Drink   1.75
# 227          519       10     Drink   1.75
# 228          226       10     Drink   1.75
# 229          682       10     Drink   1.75
# 230          450       10     Drink   1.75
# 231          358       10     Drink   1.75
# 232          677       10     Drink   1.75
# 233          250       10     Drink   1.75
# 234          351       10     Drink   1.75
# 235          937       10     Drink   1.75
# 236           64       10     Drink   1.75
# 237          912       10     Drink   1.75
# 238          772       10     Drink   1.75
# 239          919       10     Drink   1.75
# 240          574       10     Drink   1.75
# 241          338       10     Drink   1.75
# 242          225       10     Drink   1.75
# 243          475       10     Drink   1.75
# 244           51       10     Drink   1.75
# 245          809       10     Drink   1.75
# 246          584       10     Drink   1.75
# 247          274       10     Drink   1.75
# 248          151       10     Drink   1.75
# 249          535       10     Drink   1.75
#
# [250 rows x 4 columns]

# %% [markdown]
# # right_on and left_on parameters

# %%
customers=pd.read_csv("Restaurant - Customers.csv")
customers.head(2)
# Out:
#    ID First Name Last Name  Gender  Company                     Occupation
# 0   1     Joseph   Perkins    Male  Dynazzy  Community Outreach Specialist
# 1   2   Jennifer   Alvarez  Female     DabZ        Senior Quality Engineer

# %%
week2.head(2)
# Out:
#    Customer ID  Food ID
# 0          688       10
# 1          813        7

# %%
#Week2 is having the column Customer ID and customers is having the column ID and in this case simply on parameter won't work
#We have to make use of let_on and right_on parameters
#Performing left join 
week2.merge(customers,how="left",left_on="Customer ID",right_on="ID")
# Out:
#      Customer ID  Food ID   ID   First Name   Last Name  Gender       Company  \
# 0            688       10  688         Carl  Williamson    Male    Thoughtmix
# 1            813        7  813       Johnny      Walker    Male        Kayveo
# 2            495       10  495      Deborah      Little  Female    Babbleblab
# 3            189        5  189        Roger      Gordon    Male       Skilith
# 4            267        3  267      Matthew        Wood    Male        Agimba
# 5            310        5  310        Bobby        Sims    Male     Skynoodle
# 6            761        2  761    Stephanie       Olson  Female     Rhynoodle
# 7            443        5  443       Robert    Thompson    Male          Oozz
# 8            729        9  729        Roger    Lawrence    Male        Wikizz
# 9            741        8  741        Diana       Welch  Female          Eayo
# 10           847        6  847        Irene       Owens  Female         Yabox
# 11           156       10  156    Stephanie       Kelly  Female       Youopia
# 12           550        7  550       Walter      Miller    Male          Yata
# 13           620       10  620         Anne        Hill  Female      Dabshots
# 14           272        4  272   Jacqueline       Olson  Female     Gigashots
# 15           511        2  511      Phyllis      Morgan  Female        Eimbee
# 16             8        6    8      Frances       Adams  Female      Dabshots
# 17           534        7  534         Carl      Butler    Male         Npath
# 18           909        6  909       Cheryl       Davis  Female       Edgeify
# 19           732        9  732       Daniel       Grant    Male      Riffpath
# 20           372        4  372        Steve    Robinson    Male    Zoomlounge
# 21           713        1  713      Kenneth     Schmidt    Male        Skyble
# 22           496        3  496        Brian      Murray    Male         Abatz
# 23           381        9  381      Charles      Torres    Male         Tazzy
# 24            13        2   13         Ruth     Alvarez  Female   Twitterlist
# 25           101        4  101       Jeremy      Nelson    Male   Brainlounge
# 26           325        7  325       Evelyn      Powell  Female       Gabtype
# 27           674        2  674       Brenda    Gonzales  Female  Jabbersphere
# 28           564        8  564      Timothy      Bowman    Male          Oloo
# 29           578        5  578       Donald    Matthews    Male      Fiveclub
# ..           ...      ...  ...          ...         ...     ...           ...
# 220          495        2  495      Deborah      Little  Female    Babbleblab
# 221          794        6  794        Bobby    Peterson    Male      Fivespan
# 222          734       10  734        Robin      Thomas  Female          Izio
# 223          540        3  540      Jessica       Hicks  Female       Cogibox
# 224          735        2  735       Eugene     Elliott    Male        Meedoo
# 225          940        8  940       Bonnie      Bowman  Female        Avavee
# 226          571        7  571        David     Collins    Male         Midel
# 227          888        2  888        Jimmy      Wright    Male         Npath
# 228          664        6  664        Donna      Butler  Female         Miboo
# 229          343        7  343          Joe       Price    Male      Fanoodle
# 230          143        4  143  Christopher        Long    Male        Mybuzz
# 231          505        3  505      Douglas     Edwards    Male  Jabbersphere
# 232           54        8   54       Amanda       Berry  Female       Jaxspan
# 233          959        2  959        Laura    Ferguson  Female       Pixonyx
# 234          367        8  367      Mildred        Carr  Female    Jabberbean
# 235          883        8  883        Sarah         Kim  Female    Topicshots
# 236          251        9  251       Joseph    Anderson    Male         Quinu
# 237          855        4  855      Mildred      Watson  Female         Yodel
# 238          233        3  233        Robin       Lopez  Female     Wordpedia
# 239          559       10  559      Jeffrey       Henry    Male     Brightdog
# 240          734        1  734        Robin      Thomas  Female          Izio
# 241          677        3  677      Richard      Martin    Male       Gabtype
# 242          276        4  276     Kimberly       Olson  Female        Voonyx
# 243           45        8   45         Earl    Marshall    Male         Agivu
# 244          945        4  945         Anne        Reed  Female  Twitterworks
# 245          783       10  783      Phyllis       Meyer  Female        Voolia
# 246          556       10  556       Samuel      Bailey    Male        Oyoloo
# 247          547        9  547         Tina     Watkins  Female  Thoughtstorm
# 248          252        9  252      Douglas      Powell    Male       Jetwire
# 249          249        6  249      Anthony   Carpenter    Male    Shuffletag
#
#                          Occupation
# 0                  Graphic Designer
# 1                      Developer II
# 2                     VP Accounting
# 3                          Operator
# 4                  Product Engineer
# 5                 Marketing Manager
# 6                  Web Developer IV
# 7                           Teacher
# 8                    Web Designer I
# 9            Occupational Therapist
# 10                    Accountant II
# 11        Automation Specialist III
# 12   Payment Adjustment Coordinator
# 13                        Recruiter
# 14                Director of Sales
# 15         Environmental Specialist
# 16                    Developer III
# 17               Office Assistant I
# 18                  Health Coach IV
# 19               Nurse Practicioner
# 20                 Dental Hygienist
# 21                Financial Analyst
# 22           Senior Sales Associate
# 23                     Food Chemist
# 24      Mechanical Systems Engineer
# 25                 Web Developer IV
# 26                 Senior Developer
# 27            Safety Technician III
# 28                Director of Sales
# 29       Physical Therapy Assistant
# ..                              ...
# 220                   VP Accounting
# 221               Financial Analyst
# 222             Account Coordinator
# 223    Structural Analysis Engineer
# 224                    VP Marketing
# 225                Internal Auditor
# 226             Assistant Professor
# 227   Analog Circuit Design manager
# 228   Community Outreach Specialist
# 229               Marketing Manager
# 230        Accounting Assistant III
# 231              Recruiting Manager
# 232       Automation Specialist III
# 233             Electrical Engineer
# 234               Account Executive
# 235                 Cost Accountant
# 236          Administrative Officer
# 237                Product Engineer
# 238                          Editor
# 239              Environmental Tech
# 240             Account Coordinator
# 241   Analog Circuit Design manager
# 242          Occupational Therapist
# 243                Dental Hygienist
# 244               Director of Sales
# 245     Information Systems Manager
# 246                           Nurse
# 247                   Accountant II
# 248                    Geologist IV
# 249                  Health Coach I
#
# [250 rows x 8 columns]

# %%
#Above output is having two IDs meant for the same purpose
week2=week2.merge(customers,how="left",left_on="Customer ID",right_on="ID").drop("ID",axis=1)
week2.head()
# Out:
#    Customer ID  Food ID First Name   Last Name  Gender     Company  \
# 0          688       10       Carl  Williamson    Male  Thoughtmix
# 1          813        7     Johnny      Walker    Male      Kayveo
# 2          495       10    Deborah      Little  Female  Babbleblab
# 3          189        5      Roger      Gordon    Male     Skilith
# 4          267        3    Matthew        Wood    Male      Agimba
#
#          Occupation
# 0  Graphic Designer
# 1      Developer II
# 2     VP Accounting
# 3          Operator
# 4  Product Engineer

# %% [markdown]
# # Join using indexes

# %%
week1.head(2)
# Out:
#    Customer ID  Food ID
# 0          537        9
# 1           97        4

# %%
customers.head(2)
# Out:
#    ID First Name Last Name  Gender  Company                     Occupation
# 0   1     Joseph   Perkins    Male  Dynazzy  Community Outreach Specialist
# 1   2   Jennifer   Alvarez  Female     DabZ        Senior Quality Engineer

# %%
#Make the ID column as index
customers.set_index("ID",inplace=True)
customers.head(2)
# Out:
#    First Name Last Name  Gender  Company                     Occupation
# ID
# 1      Joseph   Perkins    Male  Dynazzy  Community Outreach Specialist
# 2    Jennifer   Alvarez  Female     DabZ        Senior Quality Engineer

# %%
#Case 1: Left is column, right is index
sales=week1.merge(customers,how="left",left_on="Customer ID",right_index=True)
sales.head()
# Out:
#    Customer ID  Food ID First Name Last Name  Gender    Company  \
# 0          537        9     Cheryl   Carroll  Female   Zoombeat
# 1           97        4     Amanda   Watkins  Female        Ozu
# 2          658        1    Patrick      Webb    Male  Browsebug
# 3          202        2      Louis  Campbell    Male  Rhynoodle
# 4          155        9    Carolyn      Diaz  Female   Gigazoom
#
#                       Occupation
# 0               Registered Nurse
# 1            Account Coordinator
# 2  Community Outreach Specialist
# 3     Account Representative III
# 4     Database Administrator III

# %% [raw]
# Another advantage of joining using index is that the extra duplicate column won't be created

# %%
food.head(2)
# Out:
#    Food ID Food Item  Price
# 0        1     Sushi   3.99
# 1        2   Burrito   9.99

# %%
food.set_index("Food ID",inplace=True)
food.head(2)
# Out:
#         Food Item  Price
# Food ID
# 1           Sushi   3.99
# 2         Burrito   9.99

# %%
#Case 2:Left is index and right is column
food.merge(sales,how="right",left_index=True,right_on="Food ID")
# Out:
#       Food Item  Price  Customer ID  Food ID First Name  Last Name  Gender  \
# 0         Donut   0.99          537        9     Cheryl    Carroll  Female
# 1    Quesadilla   4.25           97        4     Amanda    Watkins  Female
# 2         Sushi   3.99          658        1    Patrick       Webb    Male
# 3       Burrito   9.99          202        2      Louis   Campbell    Male
# 4         Donut   0.99          155        9    Carolyn       Diaz  Female
# 5         Salad  11.25          213        8      Keith     Foster    Male
# 6         Sushi   3.99          600        1     Sandra     Bailey  Female
# 7         Pizza   2.49          503        5     Justin    Daniels    Male
# 8          Taco   2.99           71        3    Carolyn      Reyes  Female
# 9          Taco   2.99          174        3       Anna     Miller  Female
# 10        Donut   0.99          961        9      Ralph   Richards    Male
# 11        Pizza   2.49          966        5     Robert       Ford    Male
# 12   Quesadilla   4.25          641        4      Donna  Gutierrez  Female
# 13      Burrito   9.99          288        2    Kenneth    Jackson    Male
# 14   Quesadilla   4.25          149        4   Jennifer     Oliver  Female
# 15      Burrito   9.99          954        2     Thomas    Perkins    Male
# 16        Donut   0.99          147        9    Theresa    Morales  Female
# 17        Sushi   3.99          155        1    Carolyn       Diaz  Female
# 18        Pasta  13.99          550        6     Walter     Miller    Male
# 19        Steak  24.99          101        7     Jeremy     Nelson    Male
# 20        Pasta  13.99          549        6     Harold     Rivera    Male
# 21        Pasta  13.99           75        6  Catherine  Carpenter  Female
# 22        Steak  24.99           78        7     Robert    Kennedy    Male
# 23        Pizza   2.49          514        5       Jack       Hill    Male
# 24        Steak  24.99          833        7    Carolyn       Dunn  Female
# 25        Salad  11.25          329        8     Amanda     Nguyen  Female
# 26        Drink   1.75          586       10      Doris   Mcdonald  Female
# 27        Sushi   3.99          341        1     Rachel   Robinson  Female
# 28        Drink   1.75          519       10    Lillian     Rogers  Female
# 29        Donut   0.99          680        9      Irene     Gordon  Female
# ..          ...    ...          ...      ...        ...        ...     ...
# 220       Salad  11.25          147        8    Theresa    Morales  Female
# 221  Quesadilla   4.25          745        4     Nicole      Garza  Female
# 222        Taco   2.99          184        3      Jesse    Edwards    Male
# 223       Salad  11.25          828        8       Mary      Payne  Female
# 224       Pizza   2.49          578        5     Donald   Matthews    Male
# 225  Quesadilla   4.25          491        4       Anna    Perkins  Female
# 226  Quesadilla   4.25           62        4     Andrew     Tucker    Male
# 227       Donut   0.99           77        9       Lori    Edwards  Female
# 228       Donut   0.99          506        9    Mildred    Mendoza  Female
# 229       Donut   0.99          271        9    Beverly       Ward  Female
# 230       Drink   1.75          584       10    Jeffrey    Simmons    Male
# 231       Pizza   2.49          148        5   Patricia       Reid  Female
# 232        Taco   2.99          595        3      Bruce    Kennedy    Male
# 233       Drink   1.75          274       10       Gary       Reid    Male
# 234       Sushi   3.99          646        1      Wanda       Lane  Female
# 235       Salad  11.25          520        8    Melissa    Wallace  Female
# 236       Salad  11.25          644        8      Louis     Brooks    Male
# 237       Salad  11.25          725        8      Carol    Russell  Female
# 238  Quesadilla   4.25          934        4     Joseph     Burton    Male
# 239       Drink   1.75          151       10    Brandon     Oliver    Male
# 240       Pizza   2.49          945        5       Anne       Reed  Female
# 241        Taco   2.99          343        3        Joe      Price    Male
# 242       Donut   0.99          380        9     Martha      Payne  Female
# 243  Quesadilla   4.25          911        4    Patrick       Reed    Male
# 244       Donut   0.99          621        9        Amy       Long  Female
# 245       Donut   0.99          413        9      Diane     Bailey  Female
# 246       Pasta  13.99          926        6       Anne     Wagner  Female
# 247        Taco   2.99          134        3      Diana       Hall  Female
# 248       Pasta  13.99          396        6       Juan     Romero    Male
# 249       Drink   1.75          535       10      Nancy        Cox  Female
#
#           Company                      Occupation
# 0        Zoombeat                Registered Nurse
# 1             Ozu             Account Coordinator
# 2       Browsebug   Community Outreach Specialist
# 3       Rhynoodle      Account Representative III
# 4        Gigazoom      Database Administrator III
# 5       Gigashots              VP Quality Control
# 6       Jaxnation                 Sales Associate
# 7            Oloo              Environmental Tech
# 8          Twimbo            Safety Technician IV
# 9         Innojam                     Developer I
# 10   Thoughtstorm                    Accountant I
# 11     Jabbertype       Account Representative IV
# 12        Dabtype             Assistant Professor
# 13          Voomm             Associate Professor
# 14    Topiclounge      Database Administrator III
# 15         Roodel               Account Executive
# 16          Abata          Occupational Therapist
# 17       Gigazoom      Database Administrator III
# 18           Yata  Payment Adjustment Coordinator
# 19    Brainlounge                Web Developer IV
# 20       Topdrive                 Cost Accountant
# 21         Zoozzy               Marketing Manager
# 22       Edgewire               Chemical Engineer
# 23       Blogtags             Assistant Professor
# 24          Yadel                       Recruiter
# 25         Meezzy             Associate Professor
# 26        Youfeed             Marketing Assistant
# 27        Twinder            Safety Technician IV
# 28          Eazzy                       Paralegal
# 29        Voolith       Database Administrator II
# ..            ...                             ...
# 220         Abata          Occupational Therapist
# 221     Topiczoom                 General Manager
# 222      Zoombeat          Administrative Officer
# 223       Oyonder         Assistant Media Planner
# 224      Fiveclub      Physical Therapy Assistant
# 225         Zazio                Quality Engineer
# 226        Leenti    Structural Analysis Engineer
# 227       Dabvine            Sales Representative
# 228          Vitz              Environmental Tech
# 229      Brainbox        Automation Specialist II
# 230     Flipstorm               Chemical Engineer
# 231  Shuffledrive   Analog Circuit Design manager
# 232          Mydo                       Recruiter
# 233      Fivespan             Executive Secretary
# 234         Twiyo            Help Desk Technician
# 235         Skyvu          Administrative Officer
# 236       Nlounge              VP Quality Control
# 237        BlogXS                      Pharmacist
# 238         Leexo            Compensation Analyst
# 239         Voomm                Internal Auditor
# 240  Twitterworks               Director of Sales
# 241      Fanoodle               Marketing Manager
# 242         Quinu         Assistant Media Planner
# 243   Jabberstorm         Senior Quality Engineer
# 244        Skidoo              Research Associate
# 245       Wikibox                Technical Writer
# 246         Skyba                 Legal Assistant
# 247         Quinu               Financial Advisor
# 248       Zoonder              Analyst Programmer
# 249        Trudeo              Research Associate
#
# [250 rows x 9 columns]

# %%
#Casse 3: left and right is index
week1.head(2)
# Out:
#    Customer ID  Food ID
# 0          537        9
# 1           97        4

# %%
week2.head(2)
# Out:
#    Customer ID  Food ID First Name   Last Name Gender     Company  \
# 0          688       10       Carl  Williamson   Male  Thoughtmix
# 1          813        7     Johnny      Walker   Male      Kayveo
#
#          Occupation
# 0  Graphic Designer
# 1      Developer II

# %%
week1.merge(week2,left_index=True,right_index=True)
# Out:
#      Customer ID_x  Food ID_x  Customer ID_y  Food ID_y   First Name  \
# 0              537          9            688         10         Carl
# 1               97          4            813          7       Johnny
# 2              658          1            495         10      Deborah
# 3              202          2            189          5        Roger
# 4              155          9            267          3      Matthew
# 5              213          8            310          5        Bobby
# 6              600          1            761          2    Stephanie
# 7              503          5            443          5       Robert
# 8               71          3            729          9        Roger
# 9              174          3            741          8        Diana
# 10             961          9            847          6        Irene
# 11             966          5            156         10    Stephanie
# 12             641          4            550          7       Walter
# 13             288          2            620         10         Anne
# 14             149          4            272          4   Jacqueline
# 15             954          2            511          2      Phyllis
# 16             147          9              8          6      Frances
# 17             155          1            534          7         Carl
# 18             550          6            909          6       Cheryl
# 19             101          7            732          9       Daniel
# 20             549          6            372          4        Steve
# 21              75          6            713          1      Kenneth
# 22              78          7            496          3        Brian
# 23             514          5            381          9      Charles
# 24             833          7             13          2         Ruth
# 25             329          8            101          4       Jeremy
# 26             586         10            325          7       Evelyn
# 27             341          1            674          2       Brenda
# 28             519         10            564          8      Timothy
# 29             680          9            578          5       Donald
# ..             ...        ...            ...        ...          ...
# 220            147          8            495          2      Deborah
# 221            745          4            794          6        Bobby
# 222            184          3            734         10        Robin
# 223            828          8            540          3      Jessica
# 224            578          5            735          2       Eugene
# 225            491          4            940          8       Bonnie
# 226             62          4            571          7        David
# 227             77          9            888          2        Jimmy
# 228            506          9            664          6        Donna
# 229            271          9            343          7          Joe
# 230            584         10            143          4  Christopher
# 231            148          5            505          3      Douglas
# 232            595          3             54          8       Amanda
# 233            274         10            959          2        Laura
# 234            646          1            367          8      Mildred
# 235            520          8            883          8        Sarah
# 236            644          8            251          9       Joseph
# 237            725          8            855          4      Mildred
# 238            934          4            233          3        Robin
# 239            151         10            559         10      Jeffrey
# 240            945          5            734          1        Robin
# 241            343          3            677          3      Richard
# 242            380          9            276          4     Kimberly
# 243            911          4             45          8         Earl
# 244            621          9            945          4         Anne
# 245            413          9            783         10      Phyllis
# 246            926          6            556         10       Samuel
# 247            134          3            547          9         Tina
# 248            396          6            252          9      Douglas
# 249            535         10            249          6      Anthony
#
#       Last Name  Gender       Company                      Occupation
# 0    Williamson    Male    Thoughtmix                Graphic Designer
# 1        Walker    Male        Kayveo                    Developer II
# 2        Little  Female    Babbleblab                   VP Accounting
# 3        Gordon    Male       Skilith                        Operator
# 4          Wood    Male        Agimba                Product Engineer
# 5          Sims    Male     Skynoodle               Marketing Manager
# 6         Olson  Female     Rhynoodle                Web Developer IV
# 7      Thompson    Male          Oozz                         Teacher
# 8      Lawrence    Male        Wikizz                  Web Designer I
# 9         Welch  Female          Eayo          Occupational Therapist
# 10        Owens  Female         Yabox                   Accountant II
# 11        Kelly  Female       Youopia       Automation Specialist III
# 12       Miller    Male          Yata  Payment Adjustment Coordinator
# 13         Hill  Female      Dabshots                       Recruiter
# 14        Olson  Female     Gigashots               Director of Sales
# 15       Morgan  Female        Eimbee        Environmental Specialist
# 16        Adams  Female      Dabshots                   Developer III
# 17       Butler    Male         Npath              Office Assistant I
# 18        Davis  Female       Edgeify                 Health Coach IV
# 19        Grant    Male      Riffpath              Nurse Practicioner
# 20     Robinson    Male    Zoomlounge                Dental Hygienist
# 21      Schmidt    Male        Skyble               Financial Analyst
# 22       Murray    Male         Abatz          Senior Sales Associate
# 23       Torres    Male         Tazzy                    Food Chemist
# 24      Alvarez  Female   Twitterlist     Mechanical Systems Engineer
# 25       Nelson    Male   Brainlounge                Web Developer IV
# 26       Powell  Female       Gabtype                Senior Developer
# 27     Gonzales  Female  Jabbersphere           Safety Technician III
# 28       Bowman    Male          Oloo               Director of Sales
# 29     Matthews    Male      Fiveclub      Physical Therapy Assistant
# ..          ...     ...           ...                             ...
# 220      Little  Female    Babbleblab                   VP Accounting
# 221    Peterson    Male      Fivespan               Financial Analyst
# 222      Thomas  Female          Izio             Account Coordinator
# 223       Hicks  Female       Cogibox    Structural Analysis Engineer
# 224     Elliott    Male        Meedoo                    VP Marketing
# 225      Bowman  Female        Avavee                Internal Auditor
# 226     Collins    Male         Midel             Assistant Professor
# 227      Wright    Male         Npath   Analog Circuit Design manager
# 228      Butler  Female         Miboo   Community Outreach Specialist
# 229       Price    Male      Fanoodle               Marketing Manager
# 230        Long    Male        Mybuzz        Accounting Assistant III
# 231     Edwards    Male  Jabbersphere              Recruiting Manager
# 232       Berry  Female       Jaxspan       Automation Specialist III
# 233    Ferguson  Female       Pixonyx             Electrical Engineer
# 234        Carr  Female    Jabberbean               Account Executive
# 235         Kim  Female    Topicshots                 Cost Accountant
# 236    Anderson    Male         Quinu          Administrative Officer
# 237      Watson  Female         Yodel                Product Engineer
# 238       Lopez  Female     Wordpedia                          Editor
# 239       Henry    Male     Brightdog              Environmental Tech
# 240      Thomas  Female          Izio             Account Coordinator
# 241      Martin    Male       Gabtype   Analog Circuit Design manager
# 242       Olson  Female        Voonyx          Occupational Therapist
# 243    Marshall    Male         Agivu                Dental Hygienist
# 244        Reed  Female  Twitterworks               Director of Sales
# 245       Meyer  Female        Voolia     Information Systems Manager
# 246      Bailey    Male        Oyoloo                           Nurse
# 247     Watkins  Female  Thoughtstorm                   Accountant II
# 248      Powell    Male       Jetwire                    Geologist IV
# 249   Carpenter    Male    Shuffletag                  Health Coach I
#
# [250 rows x 9 columns]
